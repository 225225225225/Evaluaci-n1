# %%
import pandas as pd

linkGit= "https://github.com/225225225225/Evaluaci-n1/raw/main/Data_Agricultura.csv"   

Data_Agricultura = pd.read_csv(linkGit)

# %%
Data_Agricultura
# Out:
#                   Country                   Official_State_Name  \
# 0                  ANGOLA                The Republic of Angola
# 1                 ALBANIA               The Republic of Albania
# 2    UNITED ARAB EMIRATES              The United Arab Emirates
# 3               ARGENTINA                The Argentine Republic
# 4                 ARMENIA               The Republic of Armenia
# ..                    ...                                   ...
# 149               URUGUAY      The Oriental Republic of Uruguay
# 150               VIETNAM    The Socialist Republic of Viet Nam
# 151       CONGO DEM. REP.  The Democratic Republic of the Congo
# 152                ZAMBIA                The Republic of Zambia
# 153              ZIMBABWE              The Republic of Zimbabwe
#
#     Internet_ccTLD iso_2 iso_3  Food_Exports  Cropland_Area  Food_Prices
# 0              .ao    AO   AGO     670760.23        5215000      166.187
# ...
